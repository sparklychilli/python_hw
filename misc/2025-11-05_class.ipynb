# %% [markdown]
# Create a variable, ask python for type

# %%
b=6
type(b)
# Out:
# int

# %%
b=6
print(type(b))
# Out:
# <class 'int'>

# %%
c=7.8
print(type(c))
# Out:
# <class 'float'>

# %%
print(type('hello'-'h'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(type('hello'-'h'))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [raw]
# TypeError: something used in wrong place, variable of wrong type used
# Traceback (most recent call last): gives you entire stack of histories, enables you to reconstruct where error happened
# Location in File where problem occured
# Code that was called
# Long Description of Error

# %% [markdown]
# Calculating Length

# %%
some_long_string = "sphinx of black quartz judge my vow"

# %%
len(some_long_string)
# Out:
# 35

# %%
some_long_string_w_linebreak =  "sphinx of black quartz judge my vow\n"

# %%
len(some_long_string_w_linebreak)
# Out:
# 36

# %%
Length only works on strings

# %%
len(12345)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 len(12345)
#
# TypeError: object of type 'int' has no len()

# %%
len(str(12345))
# Out:
# 5

# %% [markdown]
# You can also convert something into an integer/float

# %%
float("7.68")
# Out:
# 7.68

# %%
int("6758")
# Out:
# 6758

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...
