# %%
butterfly_spec_ebms = (
'Gonepteryx rhamni',
'Pieris rapae',
'Pieris napi',
'Polyommatus icarus',
'Polyommatus thersites',
'Vanessa atalanta',
'Polygonia c-ablum',
'Argynnis paphia',
'Coenonympha pamphilus',
'Pararge aegeria',
'Maniola jurtina',
'Lasiommata megera',
'Pieris',
'Polyommatinae',
'Iphiclides podalirius',
'Pieris rapae',
'Pieris napi',
'Lysandra bellargus',
'Polyommatus icarus',
'Issoria lathonia',
'Aglais io',
'Polygonia c-album',
'Coenonympha pamphilus',
'Maniola jurtina',
'Colias',
'Papilionidaea',
'Lycaenidae',
'Pieris',
'Plebejus')

# %%
#getting list with unique species
uniq_butterfly_spec_ebms = list(set(butterfly_spec_ebms)) #get unique species, make a list again
uniq_butterfly_spec_ebms.sort() #sort list alphabetically
print(uniq_butterfly_spec_ebms)
# Out:
# ['Aglais io', 'Argynnis paphia', 'Coenonympha pamphilus', 'Colias', 'Gonepteryx rhamni', 'Iphiclides podalirius', 'Issoria lathonia', 'Lasiommata megera', 'Lycaenidae', 'Lysandra bellargus', 'Maniola jurtina', 'Papilionidaea', 'Pararge aegeria', 'Pieris', 'Pieris napi', 'Pieris rapae', 'Plebejus', 'Polygonia c-ablum', 'Polygonia c-album', 'Polyommatinae', 'Polyommatus icarus', 'Polyommatus thersites', 'Vanessa atalanta']

# %%
#getting a subset of list that contains only species not in the ebms sheet of observer
ebms_csilla = ('Iphiclides podalirius',
'Pieris rapae',
'Pieris napi',
'Lysandra bellargus',
'Polyommatus icarus',
'Issoria lathonia',
'Aglais io',
'Polygonia c-album',
'Coenonympha pamphilus',
'Maniola jurtina',
'Colias',
'Papilionidaea',
'Lycaenidae',
'Pieris',
'Plebejus')

ebms_harald = ('Gonepteryx rhamni',
'Pieris rapae',
'Pieris napi',
'Polyommatus icarus',
'Polyommatus thersites',
'Vanessa atalanta',
'Polygonia c-ablum',
'Argynnis paphia',
'Coenonympha pamphilus',
'Pararge aegeria',
'Maniola jurtina',
'Lasiommata megera',
'Pieris',
'Polyommatinae')



def unique_values(list1, list2):
    """
    Returns elements that are unique to either list1 or list2.
    That is, elements that appear in exactly one list.
    """
    # Convert to sets to remove duplicates and allow set operations
    set1 = set(list1)
    set2 = set(list2)
    
    # Symmetric difference: elements in either set1 or set2 but not both
    return list(set1.symmetric_difference(set2))

print("Harald fehlt:")
unique_values(uniq_butterfly_spec_ebms, ebms_harald)
# Out:
# Harald fehlt:
# ['Iphiclides podalirius',
#  'Papilionidaea',
#  'Colias',
#  'Lycaenidae',
#  'Issoria lathonia',
#  'Lysandra bellargus',
#  'Plebejus',
#  'Polygonia c-album',
#  'Aglais io']

# %% [markdown]
# Iphiclides podalirius
# Papilionidaea
# Colias
# Lycaenidae
# Issoria lathonia
# Lysandra bellargus
# Plebejus
# Polygonia c-album
# Aglais io

# %%
print("Csilla fehlt:")
unique_values(uniq_butterfly_spec_ebms, ebms_csilla)
# Out:
# Csilla fehlt:
# ['Pararge aegeria',
#  'Polyommatinae',
#  'Vanessa atalanta',
#  'Polygonia c-ablum',
#  'Argynnis paphia',
#  'Lasiommata megera',
#  'Gonepteryx rhamni',
#  'Polyommatus thersites']

# %% [markdown]
# Pararge aegeria
# Polyommatinae
# Vanessa atalanta
# Polygonia c-ablum
# Argynnis paphia
# Lasiommata megera
# Gonepteryx rhamni
# Polyommatus thersites

# %%
#Artenliste Konrad Fiedler

fiedler_2025 = (
 "Pieris rapae"
, "Pieris rapae"
, "Polyommatus icarus"
, "Pieris rapae"
, "Polyommatus icarus"
, "Pieris rapae"
, "Polyommatus icarus"
, "Pieris rapae"
, "Aricia agestis"
, "Pieris rapae"
, "Polyommatus icarus"
, "Pieris rapae"
, "Polyommatus icarus"
, "Pieris rapae"
, "Polyommatus icarus"
, "Polyommatus icarus"
, "Polyommatus icarus"
, "Pieris rapae"
, "Celastrina argiolus"
, "Polygonia c-album"
, "Pieris rapae"
, "Polyommatus icarus"
, "Pieris rapae"
, "Cupido argiades"
, "Argynnis paphia"
, "Polyommatus icarus"
, "Maniola jurtina"
, "Pieris rapae"
, "Iphiclides podalirius"
, "Pieris rapae"
, "Polyommatus icarus"
, "Issoria lathonia"
, "Maniola jurtina"
, "Iphiclides podalirius"
, "Pieris rapae"
, "Polyommatus icarus"
, "Vanessa atalanta"
, "Polyommatus icarus"
, "Neptis rivularis"
, "Maniola jurtina"
, "Pieris rapae"
, "Celastrina argiolus"
, "Neptis rivularis"
, "Maniola jurtina"
, "Celastrina argiolus"
, "Maniola jurtina"
, "Polyommatus icarus"
, "Aglais urticae"
, "Anthocharis cardamines"
, "Pieris rapae"
, "Gonepteryx rhamni"
, "Gonepteryx rhamni")

# %%
fiedler_2025 = list(set(fiedler_2025))
"_".join(fiedler_2025)
# Out:
# 'Aglais urticae_Aricia agestis_Iphiclides podalirius_Cupido argiades_Pieris rapae_Argynnis paphia_Issoria lathonia_Neptis rivularis_Polyommatus icarus_Polygonia c-album_Anthocharis cardamines_Vanessa atalanta_Gonepteryx rhamni_Celastrina argiolus_Maniola jurtina'

# %% [markdown]
# Arten Fiedler:
# Aglais urticae
# Aricia agestis
# Iphiclides podalirius
# Cupido argiades
# Pieris rapae
# Argynnis paphia
# Issoria lathonia
# Neptis rivularis
# Polyommatus icarus
# Polygonia c-album
# Anthocharis cardamines
# Vanessa atalanta
# Gonepteryx rhamni
# Celastrina argiolus
# Maniola jurtina

# %%
inaturalist = (
"Libythea celtis",       "Polygonia c-album",    
 "Polygonia c-album",     "Vanessa atalanta",     
 "Libythea celtis",       "Pieris rapae",         
 "Vanessa atalanta",      "Pararge aegeria",      
 "Pararge aegeria",       "Vanessa atalanta",     
 "Pieris rapae",          "Gonepteryx rhamni",    
 "Vanessa atalanta",      "Iphiclides podalirius",
 "Polyommatus icarus",    "Polyommatus icarus",   
 "Polyommatus icarus",    "Vanessa atalanta",     
 "Vanessa atalanta",      "Vanessa atalanta",     
 "Polyommatus icarus",    "Polyommatus icarus",   
 "Neptis rivularis",      "Maniola jurtina",      
 "Maniola jurtina",       "Maniola jurtina",      
 "Issoria lathonia",      "Vanessa atalanta",     
 "Pieris rapae",          "Lasiommata megera",    
 "Maniola jurtina",       "Polyommatus icarus",   
 "Vanessa cardui",        "Maniola jurtina",      
 "Pieris napi",          "Maniola jurtina",      
 "Maniola jurtina",       "Maniola jurtina",      
 "Pieris napi",           "Maniola jurtina",      
 "Polyommatus icarus",    "Polyommatus icarus",   
 "Maniola jurtina",       "Maniola jurtina",      
 "Maniola jurtina",       "Polyommatus icarus",   
 "Maniola jurtina",       "Vanessa cardui",       
 "Maniola jurtina",       "Maniola jurtina",      
 "Maniola jurtina",       "Maniola jurtina",      
 "Celastrina argiolus",   "Gonepteryx rhamni",    
 "Maniola jurtina",       "Gonepteryx rhamni",    
 "Polygonia c-album",     "Vanessa atalanta",    
 "Brintesia circe",       "Maniola jurtina",      
 "Maniola jurtina",       "Polyommatus icarus",   
 "Iphiclides podalirius", "Aglais io",            
 "Issoria lathonia",      "Polyommatus icarus",   
 "Polygonia c-album",     "Maniola jurtina",      
 "Vanessa atalanta",      "Papilio machaon",      
 "Polyommatus icarus",    "Maniola jurtina",      
 "Issoria lathonia",      "Issoria lathonia",     
 "Pararge aegeria",       "Polyommatus icarus",   
 "Polyommatus icarus",    "Polyommatus icarus",   
 "Vanessa atalanta")

# %%
inaturalist = list(set(inaturalist))
print(inaturalist)
# Out:
# ['Pieris napi', 'Lasiommata megera', 'Pararge aegeria', 'Brintesia circe', 'Vanessa cardui', 'Papilio machaon', 'Libythea celtis', 'Iphiclides podalirius', 'Aglais io', 'Pieris rapae', 'Neptis rivularis', 'Issoria lathonia', 'Polygonia c-album', 'Polyommatus icarus', 'Vanessa atalanta', 'Gonepteryx rhamni', 'Celastrina argiolus', 'Maniola jurtina']
