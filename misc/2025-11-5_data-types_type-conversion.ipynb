# %% [markdown]
# # Division types

# %% [markdown]
# If num_subjects is the number of subjects taking part in a study, and num_per_survey is the number that can take part in a single survey, write an expression that calculates the number of surveys needed to reach everyone once.

# %% [markdown]
# x = num_subjects/num_per_survey

# %% [markdown]
# round(x, ndigits=None)

# %% [markdown]
# --> nevermind, doesn't work because I don't know how to force python to always round up.

# %% [markdown]
# Solution from chapter:
#
# min_num_surveys=(num_subjects - 1)//num_per_survey + 1

# %% [markdown]
# # Strings to numbers

# %% [markdown]
# print("fractional string to int:", int("3.4"))

# %% [markdown]
# Expectation: error message; int would need to get rid of quotation marks and then round, that might be too many steps

# %% [markdown]
# Note: ceiling function from math package would do that

# %%
print("fractional string to int:", int("3.4"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print("fractional string to int:", int("3.4"))
#
# ValueError: invalid literal for int() with base 10: '3.4'

# %% [markdown]
# Result --> ValueError: invalid literal for int() with base 10

# %% [markdown]
# Arithmetic with Different Types

# %% [markdown]
# Which of the following will return the floating point number 2.0? Note: there may be more than one right answer.

# %%
first = 1.0
second = "1"
third = "1.1"

# %%
first + float(second)
float(second) + float(third)
first + int(third)
first + int(float(third))
int(first) + int(float(third))
2.0 * second

# %% [markdown]
# 1, 4
# not 6 because second is a string, so the result would be "1 1"

# %% [markdown]
# work through next five chapters
