# %% [markdown]
# Fibonaccis Problem is a Recursion:
# A function that keeps calling itself
# big problem: sum of small problems
#
# r(6)=r(5)+r(4)
#
# n=1 --> 1 pair
# n=2 --> 1 pair
# n=3 --> 1 + k
#
#
# def rabbits (n, k=1):
#     if n == 1:
#         return 1
#     if n == 2:
#         return 1
#     if n == 3:
#         return 1 + k
#     return rabbits (n-1, k)+ rabbits (n-2,k)
#
#
#  new babies per generation: number of (rabbits alive two months ago) * k --> (n-2)*k
#
#  for recursion we need to set starting definitions: when do values start changing?
# small starting issues are being carried on and magnified
