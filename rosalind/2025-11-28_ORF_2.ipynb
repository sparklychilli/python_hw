# %% [markdown]
# reading frames:
# frame 1 =range(0, len(RNA_strand))
# range (1, len(RNA_strand))
# range (2, len(RNA_strand))
#
# and all 3 for reverse complement

# %%
def reverse_complement_rna(rna_strand)
    revc_rna = rna_strand[: : -1] #going from the back
    revc_rna.replace("U", "t")
    revc_rna.replace("T", "u")
    revc_rna.replace("A", "g")
    revc_rna.replace("G", "a")
    revc_
    
    

def all_reading_frames(rna_strand)
    frame_1 = rna_strand[0:]
    frame_2 = rna_strand[1:]
    frame_3 = rna_strand[2:]

# %%
if codon in ['UAA', 'UAG', 'UGA']:
