# %%
#I now want to turn on 12 batteries
#what is the joltage?
    #still consecutive
    
#function to calculate max joltage in bank
def max_joltage_battery(bank):
   
    position = 0
    joltage= ""
    for ind, pos in enumerate(bank):
        if int(pos) > position:
            position = int(pos)
            index = ind
        elif int(pos) <= first_position: #smaller or equal
            continue   
        joltage += str(position) #needs to be a string to concatenate later!
        print(index, position, joltage)
        total_joltage += int(joltage)
        return joltage, index

def max_joltage_bank(bank):
    total_joltage = 0
    index = 0
    for r in range(-12,-1,1): #but need to start with twelve, not one
        max_joltage_battery(bank[index:r])
        
    return total_joltage

# %%
example_banks = (
"987654321111111",
"811111111111119",
"234234234234278",
"818181911112111")

# %%
max_joltage_bank("987654321111111")
# Out:
# 0 9 9
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 max_joltage_bank("987654321111111")
#
# Cell In[18], line 25, in max_joltage_bank(bank)
#      23 index = 0
#      24 for r in range(-12,-1,1): #but need to start with twelve, not one
# ---> 25     max_joltage_battery(bank[index:r])
#      27 return total_joltage
#
# Cell In[18], line 18, in max_joltage_battery(bank)
#      16 joltage += str(position) #needs to be a string to concatenate later!
#      17 print(index, position, joltage)
# ---> 18 total_joltage += int(joltage)
#      19 return joltage, index
#
# UnboundLocalError: cannot access local variable 'total_joltage' where it is not associated with a value
