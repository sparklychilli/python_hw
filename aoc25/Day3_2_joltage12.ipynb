# %%
#I now want to turn on 12 batteries
#what is the joltage?
    #still consecutive
    
#function to calculate max joltage in bank
def max_joltage_battery(bank):
    joltage = ""
    index = 0
    position = 0
    
    for ind, pos in enumerate(bank):
        if int(pos) > position:
            position = int(pos)
            index = ind
        elif int(pos) <= position: #smaller or equal
            continue   
    joltage += str(position) #needs to be a string to concatenate later!
    print(index, position, joltage)
    return joltage, index

def max_joltage_bank(bank):
    joltage = ""
    index = 0
    
       
    max_joltage_battery(bank[index:-11])
    max_joltage_battery(bank[index:-10])
    max_joltage_battery(bank[index:-9])
    max_joltage_battery(bank[index:-8])
    max_joltage_battery(bank[index:-7])
    max_joltage_battery(bank[index:-6])
    max_joltage_battery(bank[index:-5])
    max_joltage_battery(bank[index:-4])
    max_joltage_battery(bank[index:-3])
    max_joltage_battery(bank[index:-2])
    max_joltage_battery(bank[index:-1])
    max_joltage_battery(bank[index:])

    return joltage

# %%
example_banks = (
"987654321111111",
"811111111111119",
"234234234234278",
"818181911112111")

# %%
max_joltage_bank("987654321111111")
# Out:
# 0 9 9
# 0 9 9
# 0 9 9
# 0 9 9
# 0 9 9
# 0 9 9
# 0 9 9
# 0 9 9
# 0 9 9
# 0 9 9
# 0 9 9
# 0 9 9
# ''
